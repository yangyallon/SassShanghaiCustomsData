# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import os

# %%
current_path = os.getcwd()
parent_path = os.path.abspath(os.path.dirname(os.getcwd()))

# %%
parent_path
# Out:
# 'd:\\YQ-SASS\\上海海关数据更新'

# %%
dir_list=os.listdir(parent_path +"\data\上海海关分贸易方式")

# %%
dir_list
# Out:
# ['2019.xlsx', '2020.xlsx', '2021.xlsx', '2022.xlsx', '2023.xlsx', '2024.xlsx']

# %%
def get_data_trade(parent_path):
   data_trade=pd.DataFrame()
   for dirname in dirlist:
      data=pd.read_excel(parent_path +"\data\上海海关分贸易方式/"+dirname)
      data.columns=['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
         'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
         'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12']
      data=data.loc[[3,4,7,17],['Unnamed: 0','Unnamed: 5','Unnamed: 9']]
      data.columns=['贸易方式','出口','进口']
      data_new=pd.melt(data,id_vars=['贸易方式'],value_vars=['出口','进口'],var_name='进出口',value_name='金额')
      data_new['年份']=dirname[0:4]
      data_trade=pd.concat([data_new,data_trade],axis=0,ignore_index=True)
   return data_trade

# %%
data_trade = get_data_trade(parent_path)

# %%
data_trade
# Out:
#                  贸易方式 进出口             金额    年份
# 0                  总值  出口  14856941.9226  2023
# 1              　　一般贸易  出口   7930250.7331  2023
# 2            　　来料加工贸易  出口    146506.1102  2023
# 3      　　海关特殊监管区域进口设备  出口              0  2023
# 4                  总值  进口  20147613.5089  2023
# 5              　　一般贸易  进口   13210089.356  2023
# 6            　　来料加工贸易  进口     88722.3033  2023
# 7      　　海关特殊监管区域进口设备  进口      13218.993  2023
# 8                 #合计  出口      1485.9419  2022
# 9              　　一般贸易  出口       768.7507  2022
# 10             　　加工贸易  出口        443.018  2022
# 11  　　　　海关保税监管场所进出境货物  出口        16.2662  2022
# 12                #合计  进口      2153.1017  2022
# 13             　　一般贸易  进口      1269.8075  2022
# 14             　　加工贸易  进口       178.4469  2022
# 15  　　　　海关保税监管场所进出境货物  进口        98.4912  2022
# 16                #合计  出口      1608.0036  2021
# 17               一般贸易  出口       807.9813  2021
# 18               补偿贸易  出口              0  2021
# 19               易货贸易  出口              0  2021
# 20                #合计  进口      2301.2399  2021
# 21               一般贸易  进口      1365.6151  2021
# 22               补偿贸易  进口              0  2021
# 23               易货贸易  进口              0  2021
# 24                #合计  出口     13725.3646  2020
# 25               一般贸易  出口       6394.412  2020
# 26               补偿贸易  出口         0.0003  2020
# 27               保税物流  出口      2399.8115  2020
# 28                #合计  进口     21103.1084  2020
# 29               一般贸易  进口     12304.5576  2020
